# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=1000,n_features=2,n_informative=2,noise=10)

# %%
df = pd.DataFrame(x,columns=['feature1','feature2'])
df['target']=y

# %%
df.shape
# Out:
# (1000, 3)

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0b807490-6b5e-4fa8-a620-45f73723182d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b807490-6b5e-4fa8-a620-45f73723182d")) {                    Plotly.newPlot(                        "0b807490-6b5e-4fa8-a620-45f73723182d",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[1.5230074076234166,-0.2387675052354217,0.12943949322121545,-1.0973423993910632,0.10388799489871556,-1.3419368119620008,-1.3002637308446439,0.36195726576805465,-0.13693541904236387,0.7399021890014928,-1.6676903258003537,0.17805570693044567,-1.1815409676917135,1.0453527879582476,0.6982147192835798,-1.5759962256249476,0.5081665648191531,-0.8128124710046145,-0.01100183559694727,3.20437993853914,0.03930108330867696,-0.9962704836863302,0.7834184091996552,2.0230976603379567,-1.7979340832358857,-1.2446670635417332,0.23401699643068233,0.07677073987599227,1.0801512753994662,-0.4233203158108072,1.136128621216921,0.08165135537908288,0.7217901640681417,-1.1302348138976113,-0.40548737584829764,0.28180478431383305,-0.5367118049420138,0.3612914457274631,0.22987593863266523,-0.1496774976437653,1.0316594547087734,1.1732328946362518,1.1098514509852317,0.4075939544750666,-0.19575702882521748,0.7409420933731602,-0.12816015720838403,-0.5187632628613444,0.4046884504609646,-0.5295821220056509,-0.2168761842055346,-0.707724638502825,1.106255268903833,-0.35029486977386987,0.14426945958564172,0.055334108365065464,-0.2745017259233908,0.5284624312350213,-0.8997053269874296,-1.0670470026156293,0.38096204836415937,1.639119809330357,-0.9606386637553017,0.8247029281320415,-0.6089968142903951,-0.6479721883028982,-0.6896196954455203,0.35137738162388965,-1.2438670554787024,-0.8774218909422432,-0.46893476769273096,0.3448589193393291,0.5679141954153936,-1.4892111824474599,0.5967365564516568,0.6953920947346568,0.9960627513098239,-2.0503529759203754,0.07842776579489605,-0.30379287080454004,0.630258275233496,-1.0080246647997722,0.07934544215714881,0.06902601986030177,2.335070535313794,-1.1871789958996064,-0.8356075717184236,-1.2027976105694527,-0.3063455648822865,0.5386404952290352,-0.6632087291749541,-0.16558246042502386,0.802127538239743,-0.7522135112711748,-0.8373317205061324,0.9255592235773217,-1.5843451090382383,-0.0988305514283761,0.3285174510773316,1.6368469333482736,2.444941694223946,0.03550994211705224,-1.057708623398325,0.38305021037977666,1.8114200692816216,-0.7476402825348973,-0.2379843655596469,-1.7810912512582906,0.8394943389483571,0.6274756954141257,0.5464447652980604,1.0900826055315846,1.349656357453918,-1.7091520319682927,0.287975334731889,-2.6696014899361704,0.9478942572588038,-2.12191162429116,-1.4945185950269586,0.26986802696257695,0.41270634253192234,-1.2983430538295548,0.8497525544790235,0.3199587712505935,-0.6585630446698488,-0.2610871396640854,0.46112684248612634,1.031608553307659,-0.12925243580090662,0.10266506288328536,-0.16198384378526834,-0.09146152978039337,-0.14777567197759767,-1.5602324252882664,-0.23229831497220735,0.5278183358183797,1.652132020006329,0.43340962498614255,0.2044931933420404,-0.20108289009438057,1.0205245348907968,1.6008585507909916,1.3508317847363709,0.059544528777031445,0.24707523894562633,-0.5670385954177177,-0.2781388323776521,0.32798922244444895,-0.5579885360453151,0.10384736931914648,-2.3711593318558237,0.7484555348056963,0.42721689293633897,0.9170234846921781,-0.7806010282910651,-0.8033236612884442,1.6134279842310095,-0.49252898112400045,-0.8435104370312906,1.500981945709985,-0.2815603964935889,0.40242414337267 ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([96.82351748, 40.76772326])

# %%
lr.intercept_
# Out:
# np.float64(-0.1337816274982324)

# %%
from sklearn.metrics import r2_score

y_pred=lr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9919764794711061

# %% [markdown]
# ### CODE FROM SCRATCH

# %%
class CustomLinearRegression:
  def __init__(self):
    self.coef_=None
    self.intercept_=None

  def fit(self,x_train,y_train):
    x_train=np.insert(x_train,0,1,axis=1)

    betas = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept_=betas[0]
    self.coef_=betas[1:]

  def predict(self,x_test):
    y_pred=np.dot(x_test,self.coef_)+self.intercept_
    return y_pred

# %%
lr = CustomLinearRegression()
lr.fit(x_train,y_train)

# %%
lr.coef_
# Out:
# array([96.82351748, 40.76772326])

# %%
lr.intercept_
# Out:
# np.float64(-0.1337816274982293)
